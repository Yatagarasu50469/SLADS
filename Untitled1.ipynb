# %%
#==================================================================
#LIBRARY IMPORTS
#==================================================================
from __future__ import absolute_import, division, print_function
import tensorflow as tf
tf.enable_eager_execution() #Evaluate all operations without building graphs
import pandas as pd
import numpy as np
import numpy.matlib as matlib
import matplotlib.pyplot as plt
import multiprocessing
import os
import PIL
import math
import glob
import re
import random
import sys
import scipy
import shutil
import time
import warnings
warnings.filterwarnings("ignore")
from IPython import display
from joblib import Parallel, delayed
from matplotlib.pyplot import figure
from PIL import Image
from scipy import misc
from scipy.io import loadmat
from scipy.io import savemat
from sklearn import linear_model
from sklearn.utils import shuffle
from sklearn.neighbors import NearestNeighbors
from skimage.measure import compare_ssim
from tqdm.auto import tqdm
from tensorflow import keras
#==================================================================

# %%
y = [1, 2, 3, 4, 5, 6, 10, 12]
y2 = [4, 5, 7, 8, 9, 0, 12, 7]
x = np.linspace(1, len(y), len(y))

# %%
from sklearn import linear_model
a = np.array([0, 1, 2, 3, 4])
b = np.array([0, 1, 2, 3, 4])
regr = linear_model.LinearRegression()
regr = reg.fit(a[:, np.newaxis], b[:, np.newaxis])
print (reg.coef_, reg.intercept_)
# Out:
# [[0.90909091]] [0.18181818]

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 2, 3, 4, 5])
plt.scatter(x, y);

from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.array([0, 1, 2, 3, 4, 5])
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.scatter(xfit, yfit);

# %%
x2 = np.array([6, 7, 8, 9, 10])
y2 = np.array([10, 20, 50, 100, 1000])
plt.scatter(x, y);

model.fit(x2[:, np.newaxis], y2)

xfit = np.array([0, 1, 2, 3, 4, 5])
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.scatter(xfit, yfit);

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
np.mean(y2)
# Out:
# 236.0

# %%
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
import numpy as np
import scipy.stats as stats
from matplotlib import rcParams

#Format the base plot
font = {'family' : 'normal', 'size' : 18}
plt.rc('font', **font)

#Add plot
f = plt.figure(figsize=(20,8))
ax1 = f.add_subplot()

fit = stats.norm.pdf(a, np.mean(a), np.std(a))
plt.plot(a,fit,'-o')
plt.hist(a,normed=True)
plt.title('Testing Statistics')

rcParams['axes.titlepad'] = 30
information = 'Mean: ' 'Standard Deviation: '  
plt.figtext(.125,.9,information,fontsize=12,ha='left')
plt.savefig('test.png')

# %%
for i in tqdm(range(0,100), desc = 'Training Images', leave = True, disable = True):
    time.sleep(0.01)

# %%
a = [1, 1]
print(len(a), a)
# Out:
# 2 [1, 1]
